# %% [markdown]
# #Inico

# %%
#entrada
oi= "Hello Word"

# %%
#saida
print=(oi)

# %% [markdown]
# #Área do Quadrado

# %%
#entrada
lado = 4
#processamento
area= lado*lado
#saida
print= ("A área do Quadro é: ",area)
