# %% [markdown]
# #Calculo de preco final de um carro

# %%
valordocarro= float(input("Me diga o valor do carro: "))
impostos= 45
distribuicao = 28
# Out:
# Me diga o valor do carro: 25000.00

# %%
impostos1 = (valordocarro*45/100) + valordocarro
valorfinaldocarro = (impostos1*28/100) + impostos1

# %%
print(f"O valor final do carro: {valorfinaldocarro}")
# Out:
# O valor final do carro: 46400.0

# %% [markdown]
# #Conversao de horas em minutos e minutos em segundos

# %%
horas = float(input("Que horas sao: "))
minutos = float(input("Que minutos sao: "))
seg = 60
# Out:
# Que horas sao: 4
# Que minutos sao: 23

# %%
conversao = minutos/60 + horas

# %%
print(f"As horas e os minutos sao equivalentes: {conversao}")
# Out:
# As horas e os minutos sao equivalentes: 4.383333333333334

# %% [markdown]
# #Calculo de hora extra

# %%
horas = float(input('Me diga o tanto de horas trabalhadas: '))
minutos = float(input('Me diga o tanto de minutos trabalhadas: '))
salarioporhora = float(input('Me diga o tanto que voce ganha por hora trabalhadas: '))
# Out:
# Me diga o tanto de horas trabalhadas: 15
# Me diga o tanto de minutos trabalhadas: 45
# Me diga o tanto que voce ganha por hora trabalhadas: 25

# %%
conclussao = minutos/60 + horas
salarioextra = (conversao*salarioporhora)*70/100 + conversao

# %%
print(f"O valor do salario extra: {salarioextra}")
# Out:
# O valor do salario extra: 291.375
